# %% [markdown]
# # Iris KNN Classification — Experiments Notebook
#
# This notebook walks through the same end-to-end pipeline as `main.py`, step by step, for interactive exploration.

# %%
import sys
from pathlib import Path

# Add project root to Python path
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")

# %% [markdown]
# ## Step 1 — Data Ingestion

# %%
from src.data_ingestion import ingest_data

df = ingest_data()
df.head()

# %% [markdown]
# ## Step 2 — Data Cleaning

# %%
from src.data_cleaning import clean_data

df = clean_data(df)
df.shape

# %% [markdown]
# ## Step 3 — Outlier Handling (IQR)

# %%
from src.outlier_handling import handle_outliers

df = handle_outliers(df)
df.describe()

# %% [markdown]
# ## Step 4 — Preprocessing

# %%
from src.preprocessing import preprocess_data

X_train, X_test, y_train, y_test, features = preprocess_data(df)
print(f"Train: {len(X_train)}, Test: {len(X_test)}")

# %% [markdown]
# ## Step 5 — Model Training

# %%
from src.model_training import train_model

model, y_pred, best_k = train_model(X_train, y_train, X_test, y_test)
print(f"Best K: {best_k}")

# %% [markdown]
# ## Step 6 — Evaluation

# %%
from src.evaluation import evaluate_model

metrics = evaluate_model(y_test, y_pred, display_plot=True)
metrics

# %% [markdown]
# ## Step 7 — Sample Prediction

# %%
from src.prediction import predict_flower

result = predict_flower(5.1, 3.5, 1.4, 0.2)
print(f"Predicted species: {result}")
